# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_excel(r"C:\Users\Brij\Desktop\Python for data science\DailyRoute_DateTime.xlsx")

# %%
data1 = data.copy()

# %%
data1.head()
# Out:
#         DATE      TIME  MODEL  CAR_YEAR  ENGINE_POWER AUTOMATIC VEHICLE_ID  \
# 0 2017-08-16  16:55:04  agile    2011.0           1.4         n       car1
# 1 2017-08-16  16:55:12  agile    2011.0           1.4         n       car1
# 2 2017-08-16  16:55:20  agile    2011.0           1.4         n       car1
# 3 2017-08-16  16:55:28  agile    2011.0           1.4         n       car1
# 4 2017-08-16  16:55:36  agile    2011.0           1.4         n       car1
#
#    BAROMETRIC_PRESSURE(KPA)  ENGINE_COOLANT_TEMP  FUEL_LEVEL  ...  \
# 0                     100.0                 80.0       0.486  ...
# 1                     100.0                 80.0       0.486  ...
# 2                     100.0                 80.0       0.486  ...
# 3                     100.0                 80.0       0.486  ...
# 4                     100.0                 80.0       0.486  ...
#
#    ENGINE_RUNTIME  THROTTLE_POS         DTC_NUMBER  TROUBLE_CODES  \
# ...

# %%
data1.columns
# Out:
# Index(['DATE', 'TIME', 'MODEL', 'CAR_YEAR', 'ENGINE_POWER', 'AUTOMATIC',
#        'VEHICLE_ID', 'BAROMETRIC_PRESSURE(KPA)', 'ENGINE_COOLANT_TEMP',
#        'FUEL_LEVEL', 'FUEL_ABS_VALUE', 'ENGINE_LOAD', 'AMBIENT_AIR_TEMP',
#        'ENGINE_RPM', 'INTAKE_MANIFOLD_PRESSURE', 'MAF', 'FUEL_TYPE',
#        'AIR_INTAKE_TEMP', 'SPEED', 'ENGINE_RUNTIME', 'THROTTLE_POS',
#        'DTC_NUMBER', 'TROUBLE_CODES', 'TIMING_ADVANCE', 'MIN', 'HOURS',
#        'DAYS_OF_WEEK', 'MONTHS', 'YEAR'],
#       dtype='object')

# %%
# Parameters : 'ENGINE_POWER', 'ENGINE_COOLANT_TEMP','FUEL_LEVEL', 'ENGINE_LOAD', 'ENGINE_RPM', 'INTAKE_MANIFOLD_PRESSURE'
               # 'AIR_INTAKE_TEMP', 'SPEED', 'THROTTLE_POS',

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=47514, step=1)

# %%
data1.shape
# Out:
# (47514, 29)

# %%
data1.size
# Out:
# 1377906

# %%
data1.describe()
# Out:
#            CAR_YEAR  ENGINE_POWER  BAROMETRIC_PRESSURE(KPA)  \
# count  47459.000000  47459.000000              10212.000000
# mean    2010.807560      1.491114                 96.404328
# std        2.933067      0.225305                  2.865433
# min     2003.000000      1.000000                 89.000000
# 25%     2009.000000      1.400000                 95.000000
# 50%     2011.000000      1.600000                 96.000000
# 75%     2012.000000      1.600000                100.000000
# max     2016.000000      1.800000                101.000000
#
#        ENGINE_COOLANT_TEMP   FUEL_LEVEL  FUEL_ABS_VALUE   ENGINE_LOAD  \
# count         33964.000000  2994.000000    47514.000000  30972.000000
# mean             81.772023     0.361005        1.137400      0.404915
# std              10.910737     0.191948        5.003938      0.214347
# min              22.000000     0.051000        0.000000      0.051000
# 25%              78.000000     0.208000        0.000000      0.255000
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47514 entries, 0 to 47513
# Data columns (total 29 columns):
# DATE                        47514 non-null datetime64[ns]
# TIME                        47514 non-null object
# MODEL                       47459 non-null object
# CAR_YEAR                    47459 non-null float64
# ENGINE_POWER                47459 non-null float64
# AUTOMATIC                   47459 non-null object
# VEHICLE_ID                  47514 non-null object
# BAROMETRIC_PRESSURE(KPA)    10212 non-null float64
# ENGINE_COOLANT_TEMP         33964 non-null float64
# FUEL_LEVEL                  2994 non-null float64
# FUEL_ABS_VALUE              47514 non-null float64
# ENGINE_LOAD                 30972 non-null float64
# AMBIENT_AIR_TEMP            3619 non-null float64
# ENGINE_RPM                  33859 non-null float64
# INTAKE_MANIFOLD_PRESSURE    25089 non-null float64
# MAF                         11828 non-null float64
# ...

# %%
data1.memory_usage()
# Out:
# Index                          128
# DATE                        380112
# TIME                        380112
# MODEL                       380112
# CAR_YEAR                    380112
# ENGINE_POWER                380112
# AUTOMATIC                   380112
# VEHICLE_ID                  380112
# BAROMETRIC_PRESSURE(KPA)    380112
# ENGINE_COOLANT_TEMP         380112
# FUEL_LEVEL                  380112
# FUEL_ABS_VALUE              380112
# ENGINE_LOAD                 380112
# AMBIENT_AIR_TEMP            380112
# ENGINE_RPM                  380112
# INTAKE_MANIFOLD_PRESSURE    380112
# MAF                         380112
# FUEL_TYPE                   380112
# AIR_INTAKE_TEMP             380112
# SPEED                       380112
# ENGINE_RUNTIME              380112
# THROTTLE_POS                380112
# DTC_NUMBER                  380112
# TROUBLE_CODES               380112
# TIMING_ADVANCE              380112
# MIN                         380112
# HOURS                       380112
# ...

# %%
data1.dtypes
# Out:
# DATE                        datetime64[ns]
# TIME                                object
# MODEL                               object
# CAR_YEAR                           float64
# ENGINE_POWER                       float64
# AUTOMATIC                           object
# VEHICLE_ID                          object
# BAROMETRIC_PRESSURE(KPA)           float64
# ENGINE_COOLANT_TEMP                float64
# FUEL_LEVEL                         float64
# FUEL_ABS_VALUE                     float64
# ENGINE_LOAD                        float64
# AMBIENT_AIR_TEMP                   float64
# ENGINE_RPM                         float64
# INTAKE_MANIFOLD_PRESSURE           float64
# MAF                                float64
# FUEL_TYPE                           object
# AIR_INTAKE_TEMP                    float64
# SPEED                              float64
# ENGINE_RUNTIME                      object
# THROTTLE_POS                       float64
# DTC_NUMBER                          object
# ...

# %%
data1.dtypes.value_counts()
# Out:
# float64           20
# object             8
# datetime64[ns]     1
# dtype: int64

# %%
data1['MODEL'].unique()
# Out:
# array(['agile', 'focus', 'fit', 'duster', nan, 'polo', 'palio', 'corolla',
#        'eco_sport', '208_allure', 'siena', 'versa', 'c3', 'voyage'],
#       dtype=object)

# %%
data1.isnull().sum()
# Out:
# DATE                            0
# TIME                            0
# MODEL                          55
# CAR_YEAR                       55
# ENGINE_POWER                   55
# AUTOMATIC                      55
# VEHICLE_ID                      0
# BAROMETRIC_PRESSURE(KPA)    37302
# ENGINE_COOLANT_TEMP         13550
# FUEL_LEVEL                  44520
# FUEL_ABS_VALUE                  0
# ENGINE_LOAD                 16542
# AMBIENT_AIR_TEMP            43895
# ENGINE_RPM                  13655
# INTAKE_MANIFOLD_PRESSURE    22425
# MAF                         35686
# FUEL_TYPE                   27509
# AIR_INTAKE_TEMP             13162
# SPEED                         985
# ENGINE_RUNTIME              35612
# THROTTLE_POS                13655
# DTC_NUMBER                    372
# TROUBLE_CODES               35589
# TIMING_ADVANCE              13352
# MIN                             2
# HOURS                           2
# DAYS_OF_WEEK                    2
# ...

# %%
data1.columns
# Out:
# Index(['DATE', 'TIME', 'MODEL', 'CAR_YEAR', 'ENGINE_POWER', 'AUTOMATIC',
#        'VEHICLE_ID', 'BAROMETRIC_PRESSURE(KPA)', 'ENGINE_COOLANT_TEMP',
#        'FUEL_LEVEL', 'FUEL_ABS_VALUE', 'ENGINE_LOAD', 'AMBIENT_AIR_TEMP',
#        'ENGINE_RPM', 'INTAKE_MANIFOLD_PRESSURE', 'MAF', 'FUEL_TYPE',
#        'AIR_INTAKE_TEMP', 'SPEED', 'ENGINE_RUNTIME', 'THROTTLE_POS',
#        'DTC_NUMBER', 'TROUBLE_CODES', 'TIMING_ADVANCE', 'MIN', 'HOURS',
#        'DAYS_OF_WEEK', 'MONTHS', 'YEAR'],
#       dtype='object')

# %%
# Parameters : 'ENGINE_POWER', 'ENGINE_COOLANT_TEMP','FUEL_LEVEL', 'ENGINE_LOAD', 'ENGINE_RPM', 'INTAKE_MANIFOLD_PRESSURE'
               # 'AIR_INTAKE_TEMP', 'SPEED', 'THROTTLE_POS',

# %%
data1 = data1.drop(['DATE','TIME','MODEL','CAR_YEAR','FUEL_LEVEL','AUTOMATIC','VEHICLE_ID','BAROMETRIC_PRESSURE(KPA)','FUEL_ABS_VALUE',
                    'AMBIENT_AIR_TEMP','MAF','FUEL_TYPE','ENGINE_RUNTIME','DTC_NUMBER', 'TROUBLE_CODES', 'TIMING_ADVANCE', 
                    'MIN', 'HOURS','DAYS_OF_WEEK', 'MONTHS', 'YEAR','TROUBLE_CODES'],axis=1)

# %%
data1.corr()
# Out:
#                           ENGINE_POWER  ENGINE_COOLANT_TEMP  ENGINE_LOAD  \
# ENGINE_POWER                  1.000000            -0.085071     0.406754
# ENGINE_COOLANT_TEMP          -0.085071             1.000000     0.200159
# ENGINE_LOAD                   0.406754             0.200159     1.000000
# ENGINE_RPM                    0.092945             0.027060     0.303054
# INTAKE_MANIFOLD_PRESSURE     -0.190935             0.092020     0.208721
# AIR_INTAKE_TEMP              -0.176283             0.465357    -0.060566
# SPEED                         0.391071             0.067198     0.318455
# THROTTLE_POS                 -0.118233             0.261160     0.385287
#
#                           ENGINE_RPM  INTAKE_MANIFOLD_PRESSURE  \
# ENGINE_POWER                0.092945                 -0.190935
# ENGINE_COOLANT_TEMP         0.027060                  0.092020
# ENGINE_LOAD                 0.303054                  0.208721
# ...

# %%
sns.pairplot(data1,kind='scatter')

# %%
sns.boxplot(y=data1['ENGINE_POWER'])

# %%
sns.boxplot(y=data1['ENGINE_COOLANT_TEMP'])

# %%
sns.boxplot(y=data1['ENGINE_LOAD'])

# %%
sns.boxplot(y=data1['ENGINE_RPM'])

# %%
sns.boxplot(y=data1['INTAKE_MANIFOLD_PRESSURE'])

# %%
sns.boxplot(y=data1['AIR_INTAKE_TEMP'])

# %%
sns.boxplot(y=data1['SPEED'])

# %%
sns.boxplot(y=data1['THROTTLE_POS'])

# %%
# Parameters : 'ENGINE_POWER', 'ENGINE_COOLANT_TEMP','FUEL_LEVEL', 'ENGINE_LOAD', 'ENGINE_RPM', 'INTAKE_MANIFOLD_PRESSURE'
               # 'AIR_INTAKE_TEMP', 'SPEED', 'THROTTLE_POS',

# %%
sns.regplot(x=data1["SPEED"], y=data1["THROTTLE_POS"], fit_reg=True)

# %%
sns.regplot(x=data1["SPEED"], y=data1["ENGINE_RPM"])

# %%
sns.regplot(x=data1["ENGINE_COOLANT_TEMP"], y=data1["ENGINE_POWER"])

# %%
sns.regplot(x=data1["INTAKE_MANIFOLD_PRESSURE"], y=data1["ENGINE_LOAD"])

# %%
sns.regplot(x=data1["ENGINE_RPM"], y=data1["AIR_INTAKE_TEMP"])

# %%
sns.regplot(x=data1["ENGINE_RPM"], y=data1["INTAKE_MANIFOLD_PRESSURE"])

# %%
data1.head()
# Out:
#    ENGINE_POWER  ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  \
# 0           1.4                 80.0        0.333      1009.0
# 1           1.4                 80.0        0.325      1003.0
# 2           1.4                 80.0        0.329       995.0
# 3           1.4                 80.0        0.325      1004.0
# 4           1.4                 80.0        0.329      1005.0
#
#    INTAKE_MANIFOLD_PRESSURE  AIR_INTAKE_TEMP  SPEED  THROTTLE_POS
# 0                      49.0             59.0    0.0         0.251
# 1                      52.0             59.0    0.0         0.251
# 2                      51.0             59.0    0.0         0.251
# 3                      51.0             60.0    0.0         0.251
# 4                      49.0             60.0    0.0         0.251

# %%
data1.shape
# Out:
# (47514, 8)

# %%
data1.isna().sum()   # INTAKE_MANIFOLD_PRESSURE has 22425 nan vallues so lets impute this with its median.
# Out:
# ENGINE_POWER                   55
# ENGINE_COOLANT_TEMP         13550
# ENGINE_LOAD                 16542
# ENGINE_RPM                  13655
# INTAKE_MANIFOLD_PRESSURE    22425
# AIR_INTAKE_TEMP             13162
# SPEED                         985
# THROTTLE_POS                13655
# dtype: int64

# %%
data1['INTAKE_MANIFOLD_PRESSURE'].fillna(data1['INTAKE_MANIFOLD_PRESSURE'].median(), inplace=True)

# %%
data1.isna().sum()
# Out:
# ENGINE_POWER                   55
# ENGINE_COOLANT_TEMP         13550
# ENGINE_LOAD                 16542
# ENGINE_RPM                  13655
# INTAKE_MANIFOLD_PRESSURE        0
# AIR_INTAKE_TEMP             13162
# SPEED                         985
# THROTTLE_POS                13655
# dtype: int64

# %%
data2=data1.dropna(thresh=8)

# %%
data2.shape
# Out:
# (29048, 8)

# %%
data2.isna().sum()
# Out:
# ENGINE_POWER                0
# ENGINE_COOLANT_TEMP         0
# ENGINE_LOAD                 0
# ENGINE_RPM                  0
# INTAKE_MANIFOLD_PRESSURE    0
# AIR_INTAKE_TEMP             0
# SPEED                       0
# THROTTLE_POS                0
# dtype: int64

# %%
data2.dtypes
# Out:
# ENGINE_POWER                float64
# ENGINE_COOLANT_TEMP         float64
# ENGINE_LOAD                 float64
# ENGINE_RPM                  float64
# INTAKE_MANIFOLD_PRESSURE    float64
# AIR_INTAKE_TEMP             float64
# SPEED                       float64
# THROTTLE_POS                float64
# dtype: object

# %%
#optimum number of clusters using elbow curve
from sklearn.cluster import KMeans

wcss = []

for i in range(1, 10):
    
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 40)
    kmeans.fit(data2)
    
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 8))
plt.plot(range(1, 10), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 120)
kmeans.fit(data2)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=120, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([4, 4, 4, ..., 1, 1, 4])

# %%
kmeans.cluster_centers_
# Out:
# array([[1.57073820e+00, 8.24931507e+01, 4.83810312e-01, 2.20349677e+03,
#         4.61742770e+01, 3.86971081e+01, 5.97646499e+01, 2.29813546e-01],
#        [1.57507840e+00, 7.98359465e+01, 3.36581614e-01, 1.32703994e+03,
#         4.60262420e+01, 4.13924740e+01, 2.86352533e+01, 1.71090444e-01],
#        [1.65737705e+00, 8.37637416e+01, 5.64695275e-01, 2.80124397e+03,
#         4.57198650e+01, 3.61885246e+01, 9.13481196e+01, 2.64734812e-01],
#        [1.56903846e+00, 8.02701923e+01, 4.02082280e-01, 1.76735275e+03,
#         4.51568681e+01, 4.02166209e+01, 4.42473901e+01, 1.90049725e-01],
#        [1.59875880e+00, 8.12711541e+01, 3.55226161e-01, 8.42783029e+02,
#         4.38757608e+01, 4.39149063e+01, 8.15455305e+00, 1.36295501e-01]])

# %%
#to know value counts in array
import numpy as np

unique, counts = np.unique(kmeans.labels_ , return_counts=True)
print (np.asarray((unique, counts)).T)
# Out:
# [[   0 5254]
#  [   1 6064]
#  [   2 2070]
#  [   3 7281]
#  [   4 8379]]

# %%
from sklearn.metrics import davies_bouldin_score  # see davies_bouldin_score from net

labels = kmeans.labels_
davies_bouldin_score(data2, labels)
# Out:
# 0.5242311355096192

# %%
data2['Cluster'] = labels
data2['Cluster']
# Out:
# C:\Users\Brij\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 47497    4
# 47499    0
# 47504    1
# 47505    1
# 47512    4
# Name: Cluster, Length: 29048, dtype: int32

# %%
data2.Cluster.value_counts()
# Out:
# 4    8379
# 3    7281
# 1    6064
# 0    5254
# 2    2070
# Name: Cluster, dtype: int64

# %%
data2.shape
# Out:
# (29048, 9)

# %%
data2.head()
# Out:
#    ENGINE_POWER  ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  \
# 0           1.4                 80.0        0.333      1009.0
# 1           1.4                 80.0        0.325      1003.0
# 2           1.4                 80.0        0.329       995.0
# 3           1.4                 80.0        0.325      1004.0
# 4           1.4                 80.0        0.329      1005.0
#
#    INTAKE_MANIFOLD_PRESSURE  AIR_INTAKE_TEMP  SPEED  THROTTLE_POS  Cluster
# 0                      49.0             59.0    0.0         0.251        4
# 1                      52.0             59.0    0.0         0.251        4
# 2                      51.0             59.0    0.0         0.251        4
# 3                      51.0             60.0    0.0         0.251        4
# 4                      49.0             60.0    0.0         0.251        4

# %%
data2.tail()
# Out:
#        ENGINE_POWER  ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  \
# 47497           1.6                 99.0        0.059      1029.0
# 47499           1.6                 94.0        0.412      2054.0
# 47504           1.6                 94.0        0.196      1185.0
# 47505           1.6                 96.0        0.251      1325.0
# 47512           1.6                 99.0        0.055       769.0
#
#        INTAKE_MANIFOLD_PRESSURE  AIR_INTAKE_TEMP  SPEED  THROTTLE_POS  Cluster
# 47497                      30.0             51.0   50.0         0.047        4
# 47499                      27.0             51.0   32.0         0.063        0
# 47504                      83.0             53.0   38.0         0.173        1
# 47505                      21.0             51.0   45.0         0.149        1
# 47512                      31.0             54.0    0.0         0.082        4

# %%
data2.shape
# Out:
# (29048, 9)

# %%
data2.insert(9, "Relative_RPM", 0.0)
rpm_max= data2['ENGINE_RPM'].max()

for i in data2.index:
    data2['Relative_RPM'][i]= data2['ENGINE_RPM'][i]/rpm_max
# Out:
# C:\Users\Brij\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Brij\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data2.insert(10, "Relative_Speed",0.0)
speed_max= data2['SPEED'].max()
for i in data2.index:
    data2['Relative_Speed'][i]= data2['SPEED'][i]/speed_max
# Out:
# C:\Users\Brij\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data2.head()
# Out:
#    ENGINE_POWER  ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  \
# 0           1.4                 80.0        0.333      1009.0
# 1           1.4                 80.0        0.325      1003.0
# 2           1.4                 80.0        0.329       995.0
# 3           1.4                 80.0        0.325      1004.0
# 4           1.4                 80.0        0.329      1005.0
#
#    INTAKE_MANIFOLD_PRESSURE  AIR_INTAKE_TEMP  SPEED  THROTTLE_POS  Cluster  \
# 0                      49.0             59.0    0.0         0.251        4
# 1                      52.0             59.0    0.0         0.251        4
# 2                      51.0             59.0    0.0         0.251        4
# 3                      51.0             60.0    0.0         0.251        4
# 4                      49.0             60.0    0.0         0.251        4
#
#    Relative_RPM  Relative_Speed
# 0      0.264413             0.0
# 1      0.262841             0.0
# 2      0.260744             0.0
# ...

# %%
sns.boxplot(x='Cluster', y='SPEED', data=data2)

# %%
sns.boxplot(x='Cluster', y='ENGINE_RPM', data=data2)

# %%
sns.boxplot(x='Cluster', y='ENGINE_LOAD', data=data2)

# %%
sns.boxplot(x='Cluster', y='THROTTLE_POS', data=data2)

# %%
sns.boxplot(x='Cluster', y='AIR_INTAKE_TEMP', data=data2)

# %%
sns.boxplot(x='Cluster', y='INTAKE_MANIFOLD_PRESSURE', data=data2)

# %%
sns.boxplot(x='Cluster', y='Relative_RPM', data=data2)

# %%
sns.boxplot(x='Cluster', y='Relative_Speed', data=data2)

# %%
df_filtered_0 = data2[data2['Cluster'] == 0]
df_filtered_1 = data2[data2['Cluster'] == 1]
df_filtered_2 = data2[data2['Cluster'] == 2]
df_filtered_3 = data2[data2['Cluster'] == 3]
df_filtered_4 = data2[data2['Cluster'] == 4]

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(df_filtered_0['SPEED'], df_filtered_0['ENGINE_RPM'])
ax.set_xlabel('SPEED')
ax.set_ylabel('ENGINE_RPM')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(df_filtered_1['SPEED'], df_filtered_1['ENGINE_RPM'])
ax.set_xlabel('SPEED')
ax.set_ylabel('ENGINE_RPM')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(df_filtered_2['SPEED'], df_filtered_2['ENGINE_RPM'])
ax.set_xlabel('SPEED')
ax.set_ylabel('ENGINE_RPM')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(df_filtered_3['SPEED'], df_filtered_3['ENGINE_RPM'])
ax.set_xlabel('SPEED')
ax.set_ylabel('ENGINE_RPM')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(df_filtered_4['SPEED'], df_filtered_4['ENGINE_RPM'])
ax.set_xlabel('SPEED')
ax.set_ylabel('ENGINE_RPM')
plt.show()

# %%
#Cluster 2 : Aggressive, Rash and very Fuel inefficient/Poor Driving
#Cluster 4: UnderConfident and Fuel Inefficient Driving

# %%
data2.drop(['Relative_RPM','Relative_Speed'], axis=1, inplace=True)
# Out:
# C:\Users\Brij\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data2.head()
# Out:
#    ENGINE_POWER  ENGINE_COOLANT_TEMP  ENGINE_LOAD  ENGINE_RPM  \
# 0           1.4                 80.0        0.333      1009.0
# 1           1.4                 80.0        0.325      1003.0
# 2           1.4                 80.0        0.329       995.0
# 3           1.4                 80.0        0.325      1004.0
# 4           1.4                 80.0        0.329      1005.0
#
#    INTAKE_MANIFOLD_PRESSURE  AIR_INTAKE_TEMP  SPEED  THROTTLE_POS  Cluster
# 0                      49.0             59.0    0.0         0.251        4
# 1                      52.0             59.0    0.0         0.251        4
# 2                      51.0             59.0    0.0         0.251        4
# 3                      51.0             60.0    0.0         0.251        4
# 4                      49.0             60.0    0.0         0.251        4

# %%
X = data2.copy().drop(["Cluster"],axis=1)#drop the alpha ticker and date
Y = data2["Cluster"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30,random_state=4)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (20333, 8)
# (20333,)
# (8715, 8)
# (8715,)

# %%
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

LogReg=LogisticRegression()
LogReg.fit(x_train,y_train)
y_pred=LogReg.predict(x_test)
accuracy_score(y_test,y_pred)*100
# Out:
# C:\Users\Brij\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Brij\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 78.89845094664372

# %%
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
accuracy_score(y_test,y_pred)*100
# Out:
# 99.96557659208261

# %%
# Naive_bayes

# %%
from sklearn.naive_bayes import GaussianNB

model=GaussianNB()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

accuracy_score(y_test,y_pred)*100
# Out:
# 92.17441193344807

# %%
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier(n_estimators=1000)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
accuracy_score(y_test,y_pred)*100
# Out:
# 99.91967871485944

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import make_scorer, classification_report
from sklearn.metrics import f1_score,recall_score

model =  MLPClassifier(activation='relu', alpha=0.0001, batch_size=32, beta_1=0.9,
              beta_2=0.999, early_stopping=False, epsilon=1e-08,
              hidden_layer_sizes=(60,), learning_rate='constant',
              learning_rate_init=0.001, max_iter=200, momentum=0.9,
              n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
              random_state=1234, shuffle=True, solver='adam', tol=0.0001,
              validation_fraction=0.1, verbose=False, warm_start=False)

# %%
model.fit(x_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size=32, beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(60,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1234, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
sklearn_mlp_train_preds = model.predict(x_train)
sklearn_mlp_validation_preds = model.predict(x_test)

# %%
print(classification_report(y_train,sklearn_mlp_train_preds))
print(classification_report(y_test,sklearn_mlp_validation_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.66      0.76      3661
#            1       0.94      0.89      0.91      4257
#            2       0.95      0.84      0.89      1466
#            3       0.76      0.97      0.85      5159
#            4       0.99      0.98      0.98      5790
#
#     accuracy                           0.89     20333
#    macro avg       0.91      0.87      0.88     20333
# weighted avg       0.90      0.89      0.89     20333
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.63      0.75      1593
#            1       0.94      0.87      0.91      1807
#            2       0.95      0.88      0.91       604
#            3       0.74      0.98      0.84      2122
#            4       0.99      0.98      0.98      2589
#
#     accuracy                           0.89      8715
#    macro avg       0.91      0.87      0.88      8715
# ...

# %%
from mlxtend.plotting import plot_learning_curves
plot_learning_curves(x_train,y_train,x_test,y_test,model,scoring='accuracy')
# Out:
# C:\Users\Brij\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Brij\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ([0.7107722577471717,
#   0.6052631578947368,
#   0.6886374815543532,
#   0.7079798352391491,
#   0.7407043084792445,
#   0.8694155258627756,
#   0.8993184852104265,
#   0.9202631255379319,
#   0.9256243510574348,
#   0.8888998180298038],
#  [0.7174985656913367,
#   0.6142283419391853,
#   0.6859437751004016,
#   0.7165806081468732,
#   0.7316121629374641,
#   0.8767641996557659,
#   0.899942627653471,
#   0.9204819277108434,
#   0.9310384394721745,
#   0.8861732644865175])

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras import regularizers, optimizers

adam = keras.optimizers.Adam(lr=0.01, decay=0.0005)

classifier=Sequential()

earlystopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(patience=5, verbose=1)

# Adding the input layer and the first hidden layer
classifier.add(Dense(output_dim = 8, init = 'uniform', activation = 'relu', input_dim = 8))

# Adding the second hidden layer
classifier.add(Dense(output_dim = 16, init = 'uniform', activation = 'relu'))

# Adding the second hidden layer
classifier.add(Dense(output_dim = 16, init = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(output_dim = 8, init = 'uniform', activation = 'softmax',kernel_regularizer=regularizers.l2()))

#Compiling the ANN
classifier.compile(optimizer = adam, loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
history=classifier.fit(x_train, y_train, validation_data=(x_test,y_test),batch_size = 10, nb_epoch = 100)
# Out:
# C:\Users\Brij\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=8, units=8, kernel_initializer="uniform")`
#   from ipykernel import kernelapp as app
# C:\Users\Brij\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=16, kernel_initializer="uniform")`
# C:\Users\Brij\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=16, kernel_initializer="uniform")`
# C:\Users\Brij\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="softmax", kernel_regularizer=<keras.reg..., units=8, kernel_initializer="uniform")`
# ...

# %%
pd.DataFrame(history.history)
# Out:
#     val_loss  val_accuracy      loss  accuracy
# 0   0.533565      0.773379  0.669342  0.715241
# 1   0.390252      0.850602  0.466860  0.808735
# 2   0.316856      0.881124  0.373275  0.852998
# 3   0.279639      0.902352  0.315113  0.884769
# 4   0.232987      0.936087  0.272485  0.904835
# ..       ...           ...       ...       ...
# 95  0.122148      0.974986  0.121260  0.973983
# 96  0.120976      0.975100  0.120672  0.974032
# 97  0.119047      0.976822  0.120366  0.975901
# 98  0.119924      0.975674  0.119916  0.975016
# 99  0.122646      0.973035  0.120397  0.975016
#
# [100 rows x 4 columns]

# %%
train_acc = history.history['accuracy']
train_loss = history.history['loss']

val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

# %%
from matplotlib import pyplot as plt #plt is a visualization module in matplotlib.  
# %matplotlib inline 
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(train_loss)
plt.plot(val_loss)

plt.subplot(1,2,2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(train_acc)
plt.plot(val_acc)
plt.show()

# %%
from sklearn.metrics import accuracy_score
perceptron_train_preds = classifier.predict_classes(x_train)
perceptron_test_preds = classifier.predict_classes(x_test)

print("Train Accuracy :",accuracy_score(y_train,perceptron_train_preds))
print("Test_Accuray   : ",accuracy_score(y_test,perceptron_test_preds))
# Out:
# Train Accuracy : 0.9740815423203659
# Test_Accuray   :  0.9730349971313826

# %%
print(classification_report(y_train,perceptron_train_preds))
print(classification_report(y_test,perceptron_test_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      3661
#            1       0.96      0.99      0.97      4257
#            2       1.00      0.91      0.95      1466
#            3       0.97      0.97      0.97      5159
#            4       0.99      0.99      0.99      5790
#
#     accuracy                           0.97     20333
#    macro avg       0.98      0.96      0.97     20333
# weighted avg       0.97      0.97      0.97     20333
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      1593
#            1       0.96      0.99      0.97      1807
#            2       0.99      0.92      0.96       604
#            3       0.96      0.97      0.97      2122
#            4       1.00      0.99      0.99      2589
#
#     accuracy                           0.97      8715
#    macro avg       0.97      0.96      0.97      8715
# ...
